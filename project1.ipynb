# %% [markdown]
# ### Project 1

# %%
import pandas as pd
import os
import warnings

# %%
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

input_file_path = "C:/Python/python_not_titanic/Data Sorting/"
output_file_path = "C:/Python/python_not_titanic/"

excel_file_list = os.listdir(input_file_path)

#print (excel_file_list)

# %%
df = pd.DataFrame()

for excel_files in excel_file_list:
        
    if excel_files.endswith(".csv"):
        
        #print (excel_files)
        
        df1 = pd.read_csv(input_file_path+excel_files)
        
        df = df.append(df1)
        
        #print(len(df))

# df = pd.concat([df1,df])
        
df.sort_values(by='RecordTime', ascending=True)  

df.to_csv(output_file_path + "Master File.csv")

df
# Out:
#                   RecordTime  ValueAsReal StateDesc QualityDesc
# 0      4/27/2020 12:42:40 AM     1.000000   Running        Good
# 1      4/27/2020 12:43:30 AM     0.000000   Stopped        Good
# 2       4/27/2020 1:41:07 AM     1.000000   Running        Good
# 3       4/27/2020 1:41:57 AM     0.000000   Stopped        Good
# 4       4/27/2020 2:43:57 AM     1.000000   Running        Good
# ...                      ...          ...       ...         ...
# 14646  5/31/2020 11:56:48 PM     9.747327    Normal        Good
# 14647  5/31/2020 11:56:57 PM     7.644443    Normal        Good
# 14648  5/31/2020 11:57:05 PM     5.634140    Normal        Good
# 14649  5/31/2020 11:57:14 PM     3.557708    Normal        Good
# 14650  5/31/2020 11:57:25 PM     1.481276    Normal        Good
#
# [1860370 rows x 4 columns]
