# %% [markdown]
# ### Project 8

# %%
import pandas as pd
import sqlite3 
import numpy as np
import plotly.express as px
import chart_studio.plotly
from chart_studio import plotly
import seaborn as sns
from sklearn import preprocessing
import warnings 

warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
con = sqlite3.connect('C:\Python\python_not_titanic\Pivoted_database_average.db')
cur = con.cursor
sql_data = pd.read_sql('SELECT [ValueAsReal.48], [Moving average] FROM Pivoted_database_average',con)
df = pd.DataFrame(sql_data) 

# fig = df.plot.line()
fig = px.line(df, x='ValueAsReal.48', y='Moving average')
fig.show()

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
# min_max_scaler=preprocessing.MinMaxScaler()
# col=df.columns
# results=min_max_scaler.fit_transform(df)
# min_max_scaler_df=pd.DataFrame(results,columns=col)
# normalize_df=(df-df.mean())/df.std()

normalized_df=(df-df.min())/(df.max()-df.min())
fig = px.line(normalized_df, x='ValueAsReal.48', y='Moving average')
fig.show()

# %%
sns.lineplot(data=normalize_df)
# Out:
# <AxesSubplot:>
